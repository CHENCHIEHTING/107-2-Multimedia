# %%
import cv2

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/My\ Drive/107-2Multimedia
# Out:
# 172705.jpg  1.jpeg  2.jpeg  3.jpeg  4.jpeg

# %%
from matplotlib import pyplot as plt

# %%
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/172705.jpg', cv2.IMREAD_ANYCOLOR)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)#
  else:
    print("Usge:python firstOpenCV3.py imageFile")
  #cv2.imshow("image",image)
  #cv2.waitKey(0)
  #cv2.destroyAllWindows()
  plt.imshow(image)
  plt.show()

# %%
image.shape
# Out:
# (1477, 1108, 3)
